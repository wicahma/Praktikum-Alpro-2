# %% [markdown]
# ## Percobaan

# %%
#Bubble Sort Ascending
def bubble2(A):
    tukar=True
    while tukar:
        tukar=False
        for j in range(len(A)-1):
            if A[j]>A[j+1]:
                A[j],A[j+1]=A[j+1],A[j]
                tukar=True
    return A

A=[1,4,3,2,78,5,4,9,8,21]
bubble2(A)
# Out:
# [1, 2, 3, 4, 4, 5, 8, 9, 21, 78]

# %% [markdown]
# ## Tugas

# %% [markdown]
# #### 1. Pengurutan descending

# %%
#Bubble Sort Ascending
def bsort_asc(data):
    tukar=True
    while tukar:
        tukar=False
        for ank1 in range(len(data)-1):
            ank2=ank1+1
            if data[ank1]>data[ank2]:
                data[ank1],data[ank2]=data[ank2],data[ank1]
                tukar=True
    print('data anda setelah diurutkan: ',data)
    return data


data=[]
#Fungsi Input data
def inp_data():
    while True:
        inp=input('Masukkan data: ')
        if inp=='00':
            break
        else:
            data.append(float(inp))
    return inp

#Fungsi Perulangan
loop='y'
while loop=='y':
    print('''==Bubble Sort Ascending==
tekan 00 untuk selesai\n''')
    inp_data()
    bsort_asc(data)
    del data[0:len(data)+1]
    print('''\ntekan sembarang untuk selesai, y untuk lanjut
Apakah anda ingin mengurutkan lagi?''')
    loop=input('==>')

print('Program selesai...')
# Out:
# ==Bubble Sort Ascending==
# tekan 00 untuk selesai
#
# Masukkan data: 1
# Masukkan data: 7
# Masukkan data: 2
# Masukkan data: 6
# Masukkan data: 3
# Masukkan data: 5.321
# Masukkan data: -423
# Masukkan data: -21.433
# Masukkan data: 12.42
# Masukkan data: 00
# data anda setelah diurutkan:  [-423.0, -21.433, 1.0, 2.0, 3.0, 5.321, 6.0, 7.0, 12.42]
#
# tekan sembarang untuk selesai, y untuk lanjut
# Apakah anda ingin mengurutkan lagi?
# ==>y
# ==Bubble Sort Ascending==
# tekan 00 untuk selesai
#
# Masukkan data: 1
# Masukkan data: 64.34
# Masukkan data: 0.75
# Masukkan data: -12.42
# Masukkan data: -53
# Masukkan data: -0.1214
# Masukkan data: 00
# data anda setelah diurutkan:  [-53.0, -12.42, -0.1214, 0.75, 1.0, 64.34]
#
# tekan sembarang untuk selesai, y untuk lanjut
# Apakah anda ingin mengurutkan lagi?
# ==>
# Program selesai...

# %%
#Bubble Sort Descending
def bsort_asc(data):
    tukar=True
    while tukar:
        tukar=False
        for ank1 in range(len(data)-1):
            ank2=ank1+1
            if data[ank1]<data[ank2]:
                data[ank1],data[ank2]=data[ank2],data[ank1]
                tukar=True
    print('data anda setelah diurutkan: ',data)
    return data

data=[]
#Fungsi Input data
def inp_data():
    while True:
        inp=input('Masukkan data: ')
        if inp=='00':
            break
        else:
            data.append(float(inp))
    return inp

#Fungsi Perulangan
loop='y'
while loop=='y':
    print('''==Bubble Sort Ascending==
tekan 00 untuk selesai\n''')
    inp_data()
    bsort_asc(data)
    del data[0:len(data)+1]
    print('''\ntekan sembarang untuk selesai, y untuk lanjut
Apakah anda ingin mengurutkan lagi?''')
    loop=input('==>')

print('Program selesai...')
# Out:
# ==Bubble Sort Ascending==
# tekan 00 untuk selesai
#
# Masukkan data: 1
# Masukkan data: 7
# Masukkan data: 4
# Masukkan data: 0.4
# Masukkan data: 0.432
# Masukkan data: -0.645
# Masukkan data: 00
# data anda setelah diurutkan:  [7.0, 4.0, 1.0, 0.432, 0.4, -0.645]
#
# tekan sembarang untuk selesai, y untuk lanjut
# Apakah anda ingin mengurutkan lagi?
# ==>
# Program selesai...

# %% [markdown]
# #### 2. Dengan modifikasi penjelasan

# %%
# Bubble Sort Ascending dengan penjelasan lebih lengkap
def bsort_asc(data):
    tukar=True
    while tukar:
        tukar=False
        for ank1 in range(len(data)-1):
            ank2=ank1+1
            if data[ank1]>data[ank2]:
                data[ank1],data[ank2]=data[ank2],data[ank1]
                print('\ntukar',data[ank1],'dengan',data[ank2])
                print('data setelah ditukar: ',data)
                tukar=True
    return data


data=[]
#Fungsi Input data
def inp_data():
    while True:
        inp=input('Masukkan data: ')
        if inp=='00':
            break
        else:
            data.append(float(inp))


#Fungsi Perulangan
loop='y'
while loop=='y':
    print('''==Bubble Sort Ascending==
tekan 00 untuk selesai\n''')
    inp_data()
    bsort_asc(data)
    print('\ndata akhir anda:',data)
    del data[0:len(data)+1]
    print('''\ntekan sembarang untuk selesai, y untuk lanjut
Apakah anda ingin mengurutkan lagi?''')
    loop=input('==>')

print('Program selesai...')
# Out:
# ==Bubble Sort Ascending==
# tekan 00 untuk selesai
#
# Masukkan data: 1
# Masukkan data: 4
# Masukkan data: 2
# Masukkan data: -0.21
# Masukkan data: -21.53
# Masukkan data: -65
# Masukkan data: 12.54
# Masukkan data: 0.234
# Masukkan data: 5.23
# Masukkan data: 00
#
# tukar 2.0 dengan 4.0
# data setelah ditukar:  [1.0, 2.0, 4.0, -0.21, -21.53, -65.0, 12.54, 0.234, 5.23]
#
# tukar -0.21 dengan 4.0
# data setelah ditukar:  [1.0, 2.0, -0.21, 4.0, -21.53, -65.0, 12.54, 0.234, 5.23]
#
# tukar -21.53 dengan 4.0
# data setelah ditukar:  [1.0, 2.0, -0.21, -21.53, 4.0, -65.0, 12.54, 0.234, 5.23]
#
# tukar -65.0 dengan 4.0
# data setelah ditukar:  [1.0, 2.0, -0.21, -21.53, -65.0, 4.0, 12.54, 0.234, 5.23]
#
# tukar 0.234 dengan 12.54
# data setelah ditukar:  [1.0, 2.0, -0.21, -21.53, -65.0, 4.0, 0.234, 12.54, 5.23]
#
# tukar 5.23 dengan 12.54
# data setelah ditukar:  [1.0, 2.0, -0.21, -21.53, -65.0, 4.0, 0.234, 5.23, 12.54]
#
# tukar -0.21 dengan 2.0
# data setelah ditukar:  [1.0, -0.21, 2.0, -21.53, -65.0, 4.0, 0.234, 5.23, 12.54]
#
# tukar -21.53 dengan 2.0
# data setelah ditukar:  [1.0, -0.21, -21.53, 2.0, -65.0, 4.0, 0.234, 5.23, 12.54]
#
# tukar -65.0 dengan 2.0
# data setelah ditukar:  [1.0, -0.21, -21.53, -65.0, 2.0, 4.0, 0.234, 5.23, 12.54]
#
# tukar 0.234 dengan 4.0
# data setelah ditukar:  [1.0, -0.21, -21.53, -65.0, 2.0, 0.234, 4.0, 5.23, 12.54]
#
# tukar -0.21 dengan 1.0
# data setelah ditukar:  [-0.21, 1.0, -21.53, -65.0, 2.0, 0.234, 4.0, 5.23, 12.54]
#
# tukar -21.53 dengan 1.0
# data setelah ditukar:  [-0.21, -21.53, 1.0, -65.0, 2.0, 0.234, 4.0, 5.23, 12.54]
#
# tukar -65.0 dengan 1.0
# data setelah ditukar:  [-0.21, -21.53, -65.0, 1.0, 2.0, 0.234, 4.0, 5.23, 12.54]
#
# tukar 0.234 dengan 2.0
# data setelah ditukar:  [-0.21, -21.53, -65.0, 1.0, 0.234, 2.0, 4.0, 5.23, 12.54]
#
# tukar -21.53 dengan -0.21
# data setelah ditukar:  [-21.53, -0.21, -65.0, 1.0, 0.234, 2.0, 4.0, 5.23, 12.54]
#
# tukar -65.0 dengan -0.21
# data setelah ditukar:  [-21.53, -65.0, -0.21, 1.0, 0.234, 2.0, 4.0, 5.23, 12.54]
#
# tukar 0.234 dengan 1.0
# data setelah ditukar:  [-21.53, -65.0, -0.21, 0.234, 1.0, 2.0, 4.0, 5.23, 12.54]
#
# tukar -65.0 dengan -21.53
# data setelah ditukar:  [-65.0, -21.53, -0.21, 0.234, 1.0, 2.0, 4.0, 5.23, 12.54]
#
# data akhir anda: [-65.0, -21.53, -0.21, 0.234, 1.0, 2.0, 4.0, 5.23, 12.54]
#
# tekan sembarang untuk selesai, y untuk lanjut
# Apakah anda ingin mengurutkan lagi?
# ==>y
# ==Bubble Sort Ascending==
# tekan 00 untuk selesai
#
# Masukkan data: 1
# Masukkan data: 7
# Masukkan data: 3
# Masukkan data: -0.32
# Masukkan data: -12
# Masukkan data: -76.8
# Masukkan data: 12.54
# Masukkan data: 0.82
# Masukkan data: 1.34
# Masukkan data: 00
#
# tukar 3.0 dengan 7.0
# data setelah ditukar:  [1.0, 3.0, 7.0, -0.32, -12.0, -76.8, 12.54, 0.82, 1.34]
#
# tukar -0.32 dengan 7.0
# data setelah ditukar:  [1.0, 3.0, -0.32, 7.0, -12.0, -76.8, 12.54, 0.82, 1.34]
#
# tukar -12.0 dengan 7.0
# data setelah ditukar:  [1.0, 3.0, -0.32, -12.0, 7.0, -76.8, 12.54, 0.82, 1.34]
#
# tukar -76.8 dengan 7.0
# data setelah ditukar:  [1.0, 3.0, -0.32, -12.0, -76.8, 7.0, 12.54, 0.82, 1.34]
#
# tukar 0.82 dengan 12.54
# data setelah ditukar:  [1.0, 3.0, -0.32, -12.0, -76.8, 7.0, 0.82, 12.54, 1.34]
#
# tukar 1.34 dengan 12.54
# data setelah ditukar:  [1.0, 3.0, -0.32, -12.0, -76.8, 7.0, 0.82, 1.34, 12.54]
#
# tukar -0.32 dengan 3.0
# data setelah ditukar:  [1.0, -0.32, 3.0, -12.0, -76.8, 7.0, 0.82, 1.34, 12.54]
#
# tukar -12.0 dengan 3.0
# data setelah ditukar:  [1.0, -0.32, -12.0, 3.0, -76.8, 7.0, 0.82, 1.34, 12.54]
#
# tukar -76.8 dengan 3.0
# data setelah ditukar:  [1.0, -0.32, -12.0, -76.8, 3.0, 7.0, 0.82, 1.34, 12.54]
#
# tukar 0.82 dengan 7.0
# data setelah ditukar:  [1.0, -0.32, -12.0, -76.8, 3.0, 0.82, 7.0, 1.34, 12.54]
#
# tukar 1.34 dengan 7.0
# data setelah ditukar:  [1.0, -0.32, -12.0, -76.8, 3.0, 0.82, 1.34, 7.0, 12.54]
#
# tukar -0.32 dengan 1.0
# data setelah ditukar:  [-0.32, 1.0, -12.0, -76.8, 3.0, 0.82, 1.34, 7.0, 12.54]
#
# tukar -12.0 dengan 1.0
# data setelah ditukar:  [-0.32, -12.0, 1.0, -76.8, 3.0, 0.82, 1.34, 7.0, 12.54]
#
# tukar -76.8 dengan 1.0
# data setelah ditukar:  [-0.32, -12.0, -76.8, 1.0, 3.0, 0.82, 1.34, 7.0, 12.54]
#
# tukar 0.82 dengan 3.0
# data setelah ditukar:  [-0.32, -12.0, -76.8, 1.0, 0.82, 3.0, 1.34, 7.0, 12.54]
#
# tukar 1.34 dengan 3.0
# data setelah ditukar:  [-0.32, -12.0, -76.8, 1.0, 0.82, 1.34, 3.0, 7.0, 12.54]
#
# tukar -12.0 dengan -0.32
# data setelah ditukar:  [-12.0, -0.32, -76.8, 1.0, 0.82, 1.34, 3.0, 7.0, 12.54]
#
# tukar -76.8 dengan -0.32
# data setelah ditukar:  [-12.0, -76.8, -0.32, 1.0, 0.82, 1.34, 3.0, 7.0, 12.54]
#
# tukar 0.82 dengan 1.0
# data setelah ditukar:  [-12.0, -76.8, -0.32, 0.82, 1.0, 1.34, 3.0, 7.0, 12.54]
#
# tukar -76.8 dengan -12.0
# data setelah ditukar:  [-76.8, -12.0, -0.32, 0.82, 1.0, 1.34, 3.0, 7.0, 12.54]
#
# data akhir anda: [-76.8, -12.0, -0.32, 0.82, 1.0, 1.34, 3.0, 7.0, 12.54]
#
# tekan sembarang untuk selesai, y untuk lanjut
# Apakah anda ingin mengurutkan lagi?
# ==>
# Program selesai...
